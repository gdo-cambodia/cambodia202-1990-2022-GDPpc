# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns
import requests

# %%
url = 'https://github.com/gdo-cambodia/cambodia202-1990-2022-GDPpc/raw/refs/heads/main/cambodia202-1990-2022-GDPpc.dta'
response = requests.get(url)

# Save the content to a local file
with open('cambodia_gdp.dta', 'wb') as f:
    f.write(response.content)

# Read the .dta file into a pandas DataFrame
df = pd.read_stata('cambodia_gdp.dta')

# %%
df.head()
# Out:
#        GID_2   id  year         province district       y      ln_y  \
# 0  KHM.1.1_2  1.0  1990  BântéayMéanchey    Malai   676.0  6.516193
# 1  KHM.1.1_2  1.0  1991  BântéayMéanchey    Malai   711.0  6.566672
# 2  KHM.1.1_2  1.0  1992  BântéayMéanchey    Malai   651.0  6.478509
# 3  KHM.1.1_2  1.0  1993  BântéayMéanchey    Malai  1026.0  6.933423
# 4  KHM.1.1_2  1.0  1994  BântéayMéanchey    Malai   625.0  6.437752
#
#    trend6_ln_y  trend100_ln_y  trend400_ln_y
# 0     6.545359       6.504154       6.428658
# 1     6.565005       6.517225       6.462579
# 2     6.579986       6.530417       6.496720
# 3     6.585900       6.544344       6.531558
# 4     6.562111       6.559102       6.567528

# %% [markdown]
# ## GDP per capita

# %%
# Describe 'y' by year
df_mean_y = df.groupby('year')['y'].describe().round(2)

# %%
fig = px.line(df_mean_y, x=df_mean_y.index, y=['mean', 'min', 'max'])
fig.update_layout(xaxis_title='Year', yaxis_title='GDP per capita')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6c711774-404b-421d-9afe-bc37c4e55a63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c711774-404b-421d-9afe-bc37c4e55a63")) {                    Plotly.newPlot(                        "6c711774-404b-421d-9afe-bc37c4e55a63",                        [{"hovertemplate":"variable=mean\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mean","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"mean","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[964.25,992.82,1019.09,1595.86,996.07,1060.95,1088.41,1092.07,1112.96,1224.87,1313.23,1389.61,1444.88,1528.88,1649.13,1841.37,2000.26,2162.5,2260.67,2236.5,2326.26,2434.11,2567.4,2697.44,2835.78,2979.55,3151.51,3317.92,3573.26,3750.23,3566.56,3642.37,3795.82],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=min\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"min","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"min","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[462.0,481.0,493.0,728.0,436.0,507.0,500.0,532.0,514.0,532.0,584.0,720.0,749.0,789.0,874.0,846.0,913.0,954.0,1038.0,994.0,1017.0,978.0,1187.0,1156.0,1085.0,1165.0,1390.0,1823.0,1810.0,2092.0,1941.0,1935.0,1946.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=max\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"max","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"max","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[3466.0,3565.0,3656.0,5645.0,3605.0,3861.0,3975.0,4012.0,4083.0,4456.0,4770.0,5048.0,5255.0,5518.0,5954.0,6654.0,7206.0,7776.0,8170.0,8120.0,8568.0,8718.0,8982.0,9370.0,9892.0,10445.0,11176.0,11244.0,11266.0,12456.0,11695.0,11896.0,12608.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f ...

# %%
# Calculate quantiles by year
yearly_quantiles = df.groupby('year')['y'].quantile([0.1, 0.25, 0.5, 0.75, 0.9]).unstack()

# Melt the DataFrame to long format
yearly_quantiles_long = yearly_quantiles.reset_index().melt(id_vars='year', var_name='quantile', value_name='y_value')

fig = px.line(yearly_quantiles_long, x='year', y='y_value', color='quantile',
              labels={'quantile': 'Percentile', 'y_value': 'y'},
              title='Time Series of Quantiles of y by Year')

fig.update_layout(xaxis_title='Year', yaxis_title='y')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1c917e29-647a-40ff-96bc-18c52b5bd4bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c917e29-647a-40ff-96bc-18c52b5bd4bc")) {                    Plotly.newPlot(                        "1c917e29-647a-40ff-96bc-18c52b5bd4bc",                        [{"hovertemplate":"Percentile=0.1\u003cbr\u003eyear=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.1","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[576.4,591.6,614.3,968.6,604.8,649.3,667.1,660.8,696.3,787.2,832.1,868.5,896.0,938.0,1006.8,1128.1,1238.1,1321.7,1367.0,1374.4,1392.4,1440.3,1526.3,1611.1,1706.1,1815.1,1901.0,2000.3,2201.2,2375.8,2274.0,2325.6,2367.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Percentile=0.25\u003cbr\u003eyear=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.25","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.25","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[649.0,677.5,691.5,1102.25,674.0,714.0,737.25,753.25,762.0,843.75,920.25,972.75,1012.75,1055.0,1145.0,1260.0,1372.25,1477.0,1514.0,1515.25,1569.25,1616.5,1709.0,1778.5,1868.75,1979.0,2094.25,2176.0,2475.25,2572.0,2513.5,2618.75,2693.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Percentile=0.5\u003cbr\u003eyear=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.5","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.5","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[765.0,776.5,792.5,1255.0,781.0,817.0,833.0,839.0,869.5,946.0,1008.5,1077.5,1121.5,1182.5,1276.0,1432.0,1540.0,1670.0,1719.5,1683.5,1758.0,1890.0,2026.0,2106.5,2209.0,2287.0,2449.5,2612.0,2883.0,2971.5,2875.5,2979.5,3129.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Percentile=0.75\u003cbr\u003eyear=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.75","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.75","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[895.25,914.5,943.0,1519.75,933.75,986.0,1020.75,1021.75,1015.0,1105.75,1206.25,1267.75,1320.5,1418.0,1507.5,1686.75,1809.5,1955.0,2038.5,2041.0,2160.25,2256.0,2432.25,2547.5,2644.75,2726.0,2896.0,3074.75,3314.75,3646.0,3418.5,3595.25,3810.75],"yaxis":"y","type":"scatter"},{"hovertemplate":"Percentile=0.9\u003cbr\u003eyear=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.9","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.9","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1530.7,1878.400000000002,1923.6000000000017,2997.100000000003,1653.9000000000003,1740.60000 ...

# %%
fig = px.box(df, x='year', y='y', hover_name= 'district', hover_data = ['province'],)
fig.update_layout(xaxis_title='Year', yaxis_title='GDP per capita')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a5419fa8-dce2-40ba-adf4-100ceef892a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5419fa8-dce2-40ba-adf4-100ceef892a9")) {                    Plotly.newPlot(                        "a5419fa8-dce2-40ba-adf4-100ceef892a9",                        [{"alignmentgroup":"True","customdata":[["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey ...

# %%
px.strip(df,
         x = 'y',
         y = 'province',
         range_x= [400, 12700],
         color = 'province',
         hover_name= 'district',
         hover_data = ['province'],
         animation_frame= 'year')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8a738e6b-59c4-48f0-a479-5754c9f3abf6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a738e6b-59c4-48f0-a479-5754c9f3abf6")) {                    Plotly.newPlot(                        "8a738e6b-59c4-48f0-a479-5754c9f3abf6",                        [{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003ey=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Malai","MongkolBorei","OuChrov","PaoyPaet","PhnumSrok","PreahNetrPreah","SereiSaophoan","SvayChek","ThmaPuok"],"legendgroup":"BântéayMéanchey","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#636efa"},"name":"BântéayMéanchey","offsetgroup":"BântéayMéanchey","orientation":"h","pointpos":0,"showlegend":true,"x":[676.0,1075.0,1899.0,1483.0,642.0,726.0,1915.0,668.0,660.0],"x0":" ","xaxis":"x","y":["BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003ey=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["DamnakChang'aeur","Kaeb"],"legendgroup":"Kep","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#EF553B"},"name":"Kep","offsetgroup":"Kep","orientation":"h","pointpos":0,"showlegend":true,"x":[617.0,622.0],"x0":" ","xaxis":"x","y":["Kep","Kep"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003ey=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ChetrBorei","Chhloung","Kracheh","PrekPrasab","Sambour","Snuol"],"legendgroup":"Krâchéh","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#00cc96"},"name":"Krâchéh","offsetgroup":"Krâchéh","orientation":"h","pointpos":0,"showlegend":true,"x":[599.0,620.0,765.0,616.0,665.0,938.0],"x0":" ","xaxis":"x","y":["Krâchéh","Krâchéh","Krâchéh","Krâchéh","Krâchéh","Krâchéh"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003ey=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Pailin","SalaKrau"],"legendgroup":"KrongPailin","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#ab63fa"},"name":"KrongPailin","offsetgroup":"KrongPailin","orientation":"h","pointpos":0,"showlegend":true,"x":[850.0,906.0],"x0":" ","xaxis":"x","y":["KrongPailin","KrongPailin"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003ey=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["KampongSeila","PreahSihanouk","PreyNob","StuengHav"],"legendgroup":"KrongPreahSihanouk","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#FFA15A"},"name":"KrongPreahSihanouk","offsetgroup":"KrongPreahSihanouk","orientation":"h","pointpos":0,"showlegend":true,"x":[718.0,3325.0,631.0,707.0],"x0":" ","xaxis":"x","y":[ ...

# %% [markdown]
# ## Trend of GDP per capita

# %%
# Describe 'trend400_ln_y' by year
df_mean_trend400_ln_y = df.groupby('year')['trend400_ln_y'].describe().round(2)

# %%
fig = px.line(df_mean_trend400_ln_y, x=df_mean_trend400_ln_y.index, y=['mean', 'min', 'max'])
fig.update_layout(xaxis_title='Year', yaxis_title='Trend of log GDP per capita')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f9d26f4c-789d-4117-9a3a-2890f2b07606" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9d26f4c-789d-4117-9a3a-2890f2b07606")) {                    Plotly.newPlot(                        "f9d26f4c-789d-4117-9a3a-2890f2b07606",                        [{"hovertemplate":"variable=mean\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mean","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"mean","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[6.75,6.78,6.81,6.84,6.87,6.9,6.94,6.97,7.01,7.05,7.1,7.14,7.19,7.25,7.3,7.35,7.41,7.46,7.52,7.57,7.62,7.67,7.73,7.78,7.82,7.87,7.92,7.97,8.02,8.06,8.11,8.15,8.19],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=min\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"min","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"min","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[6.14,6.19,6.24,6.29,6.32,6.34,6.37,6.4,6.44,6.48,6.53,6.58,6.63,6.69,6.75,6.82,6.86,6.9,6.95,6.99,7.04,7.1,7.16,7.23,7.3,7.37,7.45,7.5,7.54,7.58,7.62,7.65,7.67],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=max\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"max","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"max","orientation":"v","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":
=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0 ...

# %%
fig = px.box(df, x='year', y='trend400_ln_y', hover_name= 'district', hover_data = ['province'],)
fig.update_layout(xaxis_title='Year', yaxis_title='Trend log GDP per capita')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5e047dc0-a0da-4830-afee-0b8d869563ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e047dc0-a0da-4830-afee-0b8d869563ee")) {                    Plotly.newPlot(                        "5e047dc0-a0da-4830-afee-0b8d869563ee",                        [{"alignmentgroup":"True","customdata":[["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey"],["BântéayMéanchey ...

# %%
px.strip(df,
         x = 'trend400_ln_y',
         y = 'province',
         range_x= [6.10, 9.5],
         color = 'province',
         hover_name= 'district',
         hover_data = ['province'],
         animation_frame= 'year')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f7f03351-a500-4707-b7c7-f72a70622f53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7f03351-a500-4707-b7c7-f72a70622f53")) {                    Plotly.newPlot(                        "f7f03351-a500-4707-b7c7-f72a70622f53",                        [{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003etrend400_ln_y=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Malai","MongkolBorei","OuChrov","PaoyPaet","PhnumSrok","PreahNetrPreah","SereiSaophoan","SvayChek","ThmaPuok"],"legendgroup":"BântéayMéanchey","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#636efa"},"name":"BântéayMéanchey","offsetgroup":"BântéayMéanchey","orientation":"h","pointpos":0,"showlegend":true,"x":[6.428658,7.072807,7.579964,7.186116,6.459087,6.60569,7.555627,6.500668,6.489469],"x0":" ","xaxis":"x","y":["BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey","BântéayMéanchey"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003etrend400_ln_y=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["DamnakChang'aeur","Kaeb"],"legendgroup":"Kep","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#EF553B"},"name":"Kep","offsetgroup":"Kep","orientation":"h","pointpos":0,"showlegend":true,"x":[6.425335,6.434061],"x0":" ","xaxis":"x","y":["Kep","Kep"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003etrend400_ln_y=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ChetrBorei","Chhloung","Kracheh","PrekPrasab","Sambour","Snuol"],"legendgroup":"Krâchéh","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#00cc96"},"name":"Krâchéh","offsetgroup":"Krâchéh","orientation":"h","pointpos":0,"showlegend":true,"x":[6.3919916,6.386912,6.659232,6.4115343,6.5039244,6.836555],"x0":" ","xaxis":"x","y":["Krâchéh","Krâchéh","Krâchéh","Krâchéh","Krâchéh","Krâchéh"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003etrend400_ln_y=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Pailin","SalaKrau"],"legendgroup":"KrongPailin","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#ab63fa"},"name":"KrongPailin","offsetgroup":"KrongPailin","orientation":"h","pointpos":0,"showlegend":true,"x":[6.6024733,6.827767],"x0":" ","xaxis":"x","y":["KrongPailin","KrongPailin"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eprovince=%{y}\u003cbr\u003eyear=1990\u003cbr\u003etrend400_ln_y=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["KampongSeila","PreahSihanouk","PreyNob","StuengHav"],"legendgroup":"KrongPreahSihanouk","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"#FFA15A"},"name":"KrongPreahSihanouk","offsetgroup":"KrongPreah ...
